# %% [markdown]
# ### 作業1：
#
#
# #### 你選的這組資料為何重要？：
# 1. 可以依照顧客的購買特性去針對行銷
# 2. 針對性行銷可以減少不必要的產品資訊
# 3. 但缺少顧客的歷史購買資訊
#
# ####  資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 1. 資料提供者 : From Udemy's Machine Learning A-Z course.
# 2. 以什麼方式搜集 : 可能是會員資料，購買資訊
# 3. [資料連結]("https://www.kaggle.com/vjchoudhary7/customer-segmentation-tutorial-in-python")
#
# #### 蒐集而來的資料型態為何
# 1. CSV
#
# #### 這組資料想解決的問題如何評估?
# 1. 使用歷史資料做回測
#
# ### 作業2 :
# #### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# #### 核心問題為何？：
# 1. 顧客評價 , 下次搭乘 是否關聯
# 2. 區域 , 時間 是否關聯
# 3. 等車時間 , 顧客評價 是否關聯
# 4. 公共運輸較多地區 , 叫車數量 是否關聯
#
# #### 資料從何而來 ? :
# 1. APP log 資訊
# 2. 手機 gps 資訊
# 3. 大眾運輸分佈圖
#
# #### 蒐集而來的資料型態為何 :
# 1. 都可以
#
# #### 你要回答的問題，其如何評估 :
# 1. 將新的推薦系統上線,判斷業績量是否提升
#
# ### 作業3 :

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 12.966

# %%
def mean_squared_error(y,yp):
    #print((y - yp)**2)
    #in_bracket = []
    #for i in range(len(y)):
    #    num = y[i] - yp[i]
    #    num = pow(num,2)
    #    in_bracket.append(num)
    #print(in_bracket)
    in_bracket = (y - yp)**2
    return sum(in_bracket) / len(y)

MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 282.962

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 282.962
# The Mean absolute error is 13.465
